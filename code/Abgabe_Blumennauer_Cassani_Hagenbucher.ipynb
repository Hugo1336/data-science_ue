# %% [markdown]
# ## Explorative Datenanalyse

# %%
from pandas import read_csv

# %%
data = read_csv("../data/iris.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   instant          150 non-null    int64
#  1   sepal_length_cm  150 non-null    float64
#  2   sepal_width_cm   150 non-null    float64
#  3   petal_length_cm  150 non-null    float64
#  4   petal_width_cm   150 non-null    float64
#  5   species          150 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.2 KB

# %%
data.describe()
# Out:
#           instant  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# count  150.000000       150.000000      150.000000       150.000000
# mean    74.500000         5.843333        3.057333         3.758000
# std     43.445368         0.828066        0.435866         1.765298
# min      0.000000         4.300000        2.000000         1.000000
# 25%     37.250000         5.100000        2.800000         1.600000
# 50%     74.500000         5.800000        3.000000         4.350000
# 75%    111.750000         6.400000        3.300000         5.100000
# max    149.000000         7.900000        4.400000         6.900000
#
#        petal_width_cm     species
# count      150.000000  150.000000
# mean         1.199333    1.000000
# std          0.762238    0.819232
# min          0.100000    0.000000
# 25%          0.300000    0.000000
# 50%          1.300000    1.000000
# 75%          1.800000    2.000000
# max          2.500000    2.000000

# %% [markdown]
# # Visualiserung Sepal_lenght_cm

# %%
# !pip install matplotlib

# %%
data["sepal_length_cm"].plot()
# Out:
# <Axes: >

# %%
mean = data["sepal length (cm)"].mean()
std = data["sepal length (cm)"].std()

print(f"Mittelwert der Sepal-Länge: {mean:.2f} cm")
print(f"Standardabweichung: {std:.2f} cm")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/data-science_ue/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal length (cm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...
